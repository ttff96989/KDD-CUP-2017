# %%
import pandas as pd
import numpy as np

# %%
result0 = pd.read_csv("volume_predict_stacking_pure.csv")
result1 = pd.read_csv("../train&test_zjw/volume_predict_stacking_pure.csv")

# %%
result0.head()
# Out:
#    tollgate_id                                time_window  direction  volume
# 0            1  [2016-10-18 08:00:00,2016-10-18 08:20:00)          0   16.49
# 1            1  [2016-10-18 17:00:00,2016-10-18 17:20:00)          0   11.73
# 2            1  [2016-10-19 08:00:00,2016-10-19 08:20:00)          0   12.65
# 3            1  [2016-10-19 17:00:00,2016-10-19 17:20:00)          0   17.50
# 4            1  [2016-10-20 08:00:00,2016-10-20 08:20:00)          0   15.34

# %%
merge_result = pd.merge(result0, result1, on=["tollgate_id", "time_window", "direction"])
merge_result
# Out:
#      tollgate_id                                time_window  direction  \
# 0              1  [2016-10-18 08:00:00,2016-10-18 08:20:00)          0
# 1              1  [2016-10-18 17:00:00,2016-10-18 17:20:00)          0
# 2              1  [2016-10-19 08:00:00,2016-10-19 08:20:00)          0
# 3              1  [2016-10-19 17:00:00,2016-10-19 17:20:00)          0
# 4              1  [2016-10-20 08:00:00,2016-10-20 08:20:00)          0
# 5              1  [2016-10-20 17:00:00,2016-10-20 17:20:00)          0
# 6              1  [2016-10-21 08:00:00,2016-10-21 08:20:00)          0
# 7              1  [2016-10-21 17:00:00,2016-10-21 17:20:00)          0
# 8              1  [2016-10-22 08:00:00,2016-10-22 08:20:00)          0
# 9              1  [2016-10-22 17:00:00,2016-10-22 17:20:00)          0
# 10             1  [2016-10-23 08:00:00,2016-10-23 08:20:00)          0
# 11             1  [2016-10-23 17:00:00,2016-10-23 17:20:00)          0
# ...
