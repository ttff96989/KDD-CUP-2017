# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
volume_entry_train1 = pd.read_csv("volume_exit_train_3S.csv")
volume_entry_train1[["Unnamed: 0", "volume0", "volume1", "volume2", "volume3", "volume4", "volume5", "y"]]
# Out:
#                Unnamed: 0  volume0  volume1  volume2  volume3  volume4  \
# 0     2016-09-19 00:00:00    181.0    112.0     93.0      4.0      5.0
# 1     2016-09-19 00:20:00    112.0     93.0      4.0      5.0      4.0
# 2     2016-09-19 00:40:00     93.0      4.0      5.0      4.0      5.0
# 3     2016-09-19 01:00:00      4.0      5.0      4.0      5.0      4.0
# 4     2016-09-19 01:20:00      5.0      4.0      5.0      4.0      0.0
# 5     2016-09-19 01:40:00      4.0      5.0      4.0      0.0      5.0
# 6     2016-09-19 02:00:00      5.0      4.0      0.0      5.0      3.0
# 7     2016-09-19 02:20:00      4.0      0.0      5.0      3.0     10.0
# 8     2016-09-19 02:40:00      0.0      5.0      3.0     10.0      4.0
# 9     2016-09-19 03:00:00      5.0      3.0     10.0      4.0      7.0
# 10    2016-09-19 03:20:00      3.0     10.0      4.0      7.0      3.0
# 11    2016-09-19 03:40:00     10.0      4.0      7.0      3.0     11.0
# ...

# %%
entry_train1_y = volume_entry_train1["y"]
entry_train1_X = volume_entry_train1.copy()
del entry_train1_X["y"]

# %%
corr = volume_entry_train1.corr()
plt.figure(figsize=(10, 10))

sns.heatmap(corr, vmax=1, square=True,annot=True,cmap='cubehelix')
plt.title('Correlation between features')
