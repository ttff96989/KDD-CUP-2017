# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
volume_entry_train = pd.read_csv("volume_exit_test_1Soffset0.csv",index_col="Unnamed: 0")
print volume_entry_train.columns
volume_entry_train.head()
# Out:
# Index([u'cargo_count0', u'cargo_count1', u'cargo_count2', u'cargo_count3',
#        u'cargo_count4', u'cargo_count5', u'cargo_model0', u'cargo_model1',
#        u'cargo_model2', u'cargo_model3', u'cargo_model4', u'cargo_model5',
#        u'cargo_model_avg0', u'cargo_model_avg1', u'cargo_model_avg2',
#        u'cargo_model_avg3', u'cargo_model_avg4', u'cargo_model_avg5',
#        u'etc_count0', u'etc_count1', u'etc_count2', u'etc_count3',
#        u'etc_count4', u'etc_count5', u'no_count0', u'no_count1', u'no_count2',
#        u'no_count3', u'no_count4', u'no_count5', u'passenger_count0',
#        u'passenger_count1', u'passenger_count2', u'passenger_count3',
#        u'passenger_count4', u'passenger_count5', u'passenger_model0',
#        u'passenger_model1', u'passenger_model2', u'passenger_model3',
#        u'passenger_model4', u'passenger_model5', u'passenger_model_avg0',
#        u'passenger_model_avg1', u'passenger_model_avg2',
# ...

# %%
for i in range(len(volume_entry_train.columns)):
    print str(i) + " " + volume_entry_train.columns[i]
# Out:
# 0 cargo_count0
# 1 cargo_count1
# 2 cargo_count2
# 3 cargo_count3
# 4 cargo_count4
# 5 cargo_count5
# 6 cargo_model0
# 7 cargo_model1
# 8 cargo_model2
# 9 cargo_model3
# 10 cargo_model4
# 11 cargo_model5
# 12 cargo_model_avg0
# 13 cargo_model_avg1
# 14 cargo_model_avg2
# 15 cargo_model_avg3
# 16 cargo_model_avg4
# 17 cargo_model_avg5
# 18 etc_count0
# 19 etc_count1
# 20 etc_count2
# 21 etc_count3
# 22 etc_count4
# 23 etc_count5
# 24 no_count0
# 25 no_count1
# 26 no_count2
# 27 no_count3
# 28 no_count4
# 29 no_count5
# 30 passenger_count0
# 31 passenger_count1
# 32 passenger_count2
# 33 passenger_count3
# 34 passenger_count4
# 35 passenger_count5
# 36 passenger_model0
# 37 passenger_model1
# 38 passenger_model2
# 39 passenger_model3
# 40 passenger_model4
# 41 passenger_model5
# 42 passenger_model_avg0
# 43 passenger_model_avg1
# 44 passenger_model_avg2
# 45 passenger_model_avg3
# 46 passenger_model_avg4
# 47 passenger_model_avg5
# 48 vehicle_model0
# 49 vehicle_model1
# ...

# %%
volume_entry_train = pd.read_csv("volume_exit_train_1Soffset0.csv",index_col="Unnamed: 0")
for i in range(len(volume_entry_train.columns)):
    print str(i) + " " + volume_entry_train.columns[i]
# Out:
# 0 cargo_count0
# 1 cargo_count1
# 2 cargo_count2
# 3 cargo_count3
# 4 cargo_count4
# 5 cargo_count5
# 6 cargo_model0
# 7 cargo_model1
# 8 cargo_model2
# 9 cargo_model3
# 10 cargo_model4
# 11 cargo_model5
# 12 cargo_model_avg0
# 13 cargo_model_avg1
# 14 cargo_model_avg2
# 15 cargo_model_avg3
# 16 cargo_model_avg4
# 17 cargo_model_avg5
# 18 etc_count0
# 19 etc_count1
# 20 etc_count2
# 21 etc_count3
# 22 etc_count4
# 23 etc_count5
# 24 no_count0
# 25 no_count1
# 26 no_count2
# 27 no_count3
# 28 no_count4
# 29 no_count5
# 30 passenger_count0
# 31 passenger_count1
# 32 passenger_count2
# 33 passenger_count3
# 34 passenger_count4
# 35 passenger_count5
# 36 passenger_model0
# 37 passenger_model1
# 38 passenger_model2
# 39 passenger_model3
# 40 passenger_model4
# 41 passenger_model5
# 42 passenger_model_avg0
# 43 passenger_model_avg1
# 44 passenger_model_avg2
# 45 passenger_model_avg3
# 46 passenger_model_avg4
# 47 passenger_model_avg5
# 48 vehicle_model0
# 49 vehicle_model1
# ...
