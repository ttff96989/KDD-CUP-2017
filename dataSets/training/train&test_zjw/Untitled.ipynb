# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
volume_entry_train = pd.read_csv("volume_entry_train_1Soffset0.csv",index_col="Unnamed: 0")
volume_entry_train
# Out:
#                      cargo_count0  cargo_count1  cargo_count2  cargo_count3  \
# 2016-09-19 00:00:00           3.0           0.0           2.0           3.0
# 2016-09-19 00:20:00           0.0           2.0           3.0           3.0
# 2016-09-19 00:40:00           2.0           3.0           3.0           1.0
# 2016-09-19 01:00:00           3.0           3.0           1.0           3.0
# 2016-09-19 01:20:00           3.0           1.0           3.0           7.0
# 2016-09-19 01:40:00           1.0           3.0           7.0           5.0
# 2016-09-19 02:00:00           3.0           7.0           5.0           4.0
# 2016-09-19 02:20:00           7.0           5.0           4.0           1.0
# 2016-09-19 02:40:00           5.0           4.0           1.0           4.0
# 2016-09-19 03:00:00           4.0           1.0           4.0           4.0
# 2016-09-19 03:20:00           1.0           4.0           4.0           4.0
# ...

# %%
volume_entry_test = pd.read_csv("volume_entry_test_1Soffset0.csv", index_col="Unnamed: 0")

# %%
entry_train_without_y = volume_entry_train.copy()
del entry_train_without_y["y"]
is_right = True
for i in range(volume_entry_test.shape[1]):
    if volume_entry_test.columns[i] != entry_train_without_y.columns[i]:
        is_right  = is_right & False
is_right
# Out:
# True

# %%
for i in range(len(volume_entry_train.columns)):
    print str(i) + " " + volume_entry_train.columns[i]
# Out:
# 0 cargo_count0
# 1 cargo_count1
# 2 cargo_count2
# 3 cargo_count3
# 4 cargo_count4
# 5 cargo_count5
# 6 cargo_model0
# 7 cargo_model1
# 8 cargo_model2
# 9 cargo_model3
# 10 cargo_model4
# 11 cargo_model5
# 12 cargo_model_avg0
# 13 cargo_model_avg1
# 14 cargo_model_avg2
# 15 cargo_model_avg3
# 16 cargo_model_avg4
# 17 cargo_model_avg5
# 18 etc_count0
# 19 etc_count1
# 20 etc_count2
# 21 etc_count3
# 22 etc_count4
# 23 etc_count5
# 24 no_count0
# 25 no_count1
# 26 no_count2
# 27 no_count3
# 28 no_count4
# 29 no_count5
# 30 passenger_count0
# 31 passenger_count1
# 32 passenger_count2
# 33 passenger_count3
# 34 passenger_count4
# 35 passenger_count5
# 36 passenger_model0
# 37 passenger_model1
# 38 passenger_model2
# 39 passenger_model3
# 40 passenger_model4
# 41 passenger_model5
# 42 passenger_model_avg0
# 43 passenger_model_avg1
# 44 passenger_model_avg2
# 45 passenger_model_avg3
# 46 passenger_model_avg4
# 47 passenger_model_avg5
# 48 vehicle_model0
# 49 vehicle_model1
# ...

# %%
volume_entry_train = pd.read_csv("volume_exit_train_1Soffset0.csv",index_col="Unnamed: 0")
for i in range(len(volume_entry_train.columns)):
    print str(i) + " " + volume_entry_train.columns[i]
# Out:
# 0 cargo_count0
# 1 cargo_count1
# 2 cargo_count2
# 3 cargo_count3
# 4 cargo_count4
# 5 cargo_count5
# 6 cargo_model0
# 7 cargo_model1
# 8 cargo_model2
# 9 cargo_model3
# 10 cargo_model4
# 11 cargo_model5
# 12 cargo_model_avg0
# 13 cargo_model_avg1
# 14 cargo_model_avg2
# 15 cargo_model_avg3
# 16 cargo_model_avg4
# 17 cargo_model_avg5
# 18 etc_count0
# 19 etc_count1
# 20 etc_count2
# 21 etc_count3
# 22 etc_count4
# 23 etc_count5
# 24 no_count0
# 25 no_count1
# 26 no_count2
# 27 no_count3
# 28 no_count4
# 29 no_count5
# 30 passenger_count0
# 31 passenger_count1
# 32 passenger_count2
# 33 passenger_count3
# 34 passenger_count4
# 35 passenger_count5
# 36 passenger_model0
# 37 passenger_model1
# 38 passenger_model2
# 39 passenger_model3
# 40 passenger_model4
# 41 passenger_model5
# 42 passenger_model_avg0
# 43 passenger_model_avg1
# 44 passenger_model_avg2
# 45 passenger_model_avg3
# 46 passenger_model_avg4
# 47 passenger_model_avg5
# 48 vehicle_model0
# 49 vehicle_model1
# ...
