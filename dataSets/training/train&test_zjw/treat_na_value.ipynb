# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv("volume_entry_train_1Soffset0.csv")
train_df.head()
# Out:
#             Unnamed: 0  cargo_count0  cargo_count1  cargo_count2  \
# 0  2016-09-19 00:00:00           3.0           0.0           2.0
# 1  2016-09-19 00:20:00           0.0           2.0           3.0
# 2  2016-09-19 00:40:00           2.0           3.0           3.0
# 3  2016-09-19 01:00:00           3.0           3.0           1.0
# 4  2016-09-19 01:20:00           3.0           1.0           3.0
#
#    cargo_count3  cargo_count4  cargo_count5  cargo_model0  cargo_model1  \
# 0           3.0           3.0           1.0          12.0           0.0
# 1           3.0           1.0           3.0           0.0           7.0
# 2           1.0           3.0           7.0           7.0          15.0
# 3           3.0           7.0           5.0          15.0          10.0
# 4           7.0           5.0           4.0          10.0           5.0
#
#    cargo_model2   ...     volume_all  etc_all_count  vehicle_all_model_avg  \
# ...

# %%
print train_df.shape
train_df.info()
# Out:
# (2082, 84)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2082 entries, 0 to 2081
# Data columns (total 84 columns):
# Unnamed: 0                 2082 non-null object
# cargo_count0               2082 non-null float64
# cargo_count1               2082 non-null float64
# cargo_count2               2082 non-null float64
# cargo_count3               2082 non-null float64
# cargo_count4               2082 non-null float64
# cargo_count5               2082 non-null float64
# cargo_model0               2082 non-null float64
# cargo_model1               2082 non-null float64
# cargo_model2               2082 non-null float64
# cargo_model3               2082 non-null float64
# cargo_model4               2082 non-null float64
# cargo_model5               2082 non-null float64
# cargo_model_avg0           1508 non-null float64
# cargo_model_avg1           1508 non-null float64
# cargo_model_avg2           1509 non-null float64
# cargo_model_avg3           1508 non-null float64
# ...

# %%
train_df.dropna().shape
# Out:
# (1090, 84)

# %%
# cargo_count0~cargo_count5, etc_count0~etc_count5, no_count0~no_count5, 
# passenger_count0~passenger_count5, vehicle_model0~vehicle_model5,
