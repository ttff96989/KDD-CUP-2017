# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
volume_entry_train = pd.read_csv("volume_entry_train_1Soffset0.csv",index_col="Unnamed: 0")
for item in volume_entry_train.columns:
    print item
# Out:
# cargo_count0
# cargo_count1
# cargo_count2
# cargo_count3
# cargo_count4
# cargo_count5
# cargo_model0
# cargo_model1
# cargo_model2
# cargo_model3
# cargo_model4
# cargo_model5
# cargo_model_avg0
# cargo_model_avg1
# cargo_model_avg2
# cargo_model_avg3
# cargo_model_avg4
# cargo_model_avg5
# etc_count0
# etc_count1
# etc_count2
# etc_count3
# etc_count4
# etc_count5
# no_count0
# no_count1
# no_count2
# no_count3
# no_count4
# no_count5
# passenger_count0
# passenger_count1
# passenger_count2
# passenger_count3
# passenger_count4
# passenger_count5
# passenger_model0
# passenger_model1
# passenger_model2
# passenger_model3
# passenger_model4
# passenger_model5
# passenger_model_avg0
# passenger_model_avg1
# passenger_model_avg2
# passenger_model_avg3
# passenger_model_avg4
# passenger_model_avg5
# vehicle_model0
# vehicle_model1
# vehicle_model2
# vehicle_model3
# vehicle_model4
# vehicle_model5
# vehicle_model_avg0
# vehicle_model_avg1
# vehicle_model_avg2
# vehicle_model_avg3
# vehicle_model_avg4
# vehicle_model_avg5
# volume0
# volume1
# volume2
# volume3
# volume4
# volume5
# y
# vehicle_all_model
# cargo_all_model
# passenger_all_model
# no_all_count
# cargo_all_count
# passenger_all_count
# volume_all
# etc_all_count
# vehicle_all_model_avg
# cargo_all_model_avg
# passenger_all_model_avg
# vehicle_all_model_avg_S2
# vehicle_all_model_avg_S3
# vehicle_all_model_avg_sqrt
# vehicle_model_avg5_S2
# vehicle_model_avg5_S3
# vehicle_model_avg5_sqrt
# vehicle_model_avg4_S2
# vehicle_model_avg4_S3
# vehicle_model_avg4_sqrt
# vehicle_model_avg3_S2
# vehicle_model_avg3_S3
# vehicle_model_avg3_sqrt
# vehicle_model_avg2_S2
# vehicle_model_avg2_S3
# vehicle_model_avg2_sqrt
# vehicle_model_avg1_S2
# vehicle_model_avg1_S3
# vehicle_model_avg1_sqrt
# vehicle_model_avg0_S2
# vehicle_model_avg0_S3
# passenger_all_model_avg_S2
# passenger_all_model_avg_S3
# no_all_count_S2
# no_all_count_S3
# no_all_count_sqrt
# no_count4_S2
# no_count4_S3
# no_count4_sqrt
# volume1_S2
# volume1_S3
# volume1_sqrt
# no_count5_S2
# no_count5_S3
# no_count5_sqrt
# volume2_S2
# volume2_S3
# volume2_sqrt
# volume3_S2
# volume3_S3
# volume3_sqrt
# volume_all_S2
# volume_all_S3
# volume_all_sqrt
# volume4_S2
# volume4_S3
# volume4_sqrt
# volume5_S2
# volume5_S3
# volume5_sqrt
# is_eight
# is_nine
# is_eighteen
# is_seventeen
# minute
# week
# weekend

# %%
volume_entry_test = pd.read_csv("volume_entry_test_1Soffset0.csv", index_col="Unnamed: 0")

# %%
entry_train_without_y = volume_entry_train.copy()
del entry_train_without_y["y"]
is_right = True
for i in range(volume_entry_test.shape[1]):
    if volume_entry_test.columns[i] != entry_train_without_y.columns[i]:
        is_right  = is_right & False
is_right
# Out:
# True

# %%
for i in range(len(volume_entry_train.columns)):
    print str(i) + " " + volume_entry_train.columns[i]
# Out:
# 0 cargo_count0
# 1 cargo_count1
# 2 cargo_count2
# 3 cargo_count3
# 4 cargo_count4
# 5 cargo_count5
# 6 cargo_model0
# 7 cargo_model1
# 8 cargo_model2
# 9 cargo_model3
# 10 cargo_model4
# 11 cargo_model5
# 12 cargo_model_avg0
# 13 cargo_model_avg1
# 14 cargo_model_avg2
# 15 cargo_model_avg3
# 16 cargo_model_avg4
# 17 cargo_model_avg5
# 18 etc_count0
# 19 etc_count1
# 20 etc_count2
# 21 etc_count3
# 22 etc_count4
# 23 etc_count5
# 24 no_count0
# 25 no_count1
# 26 no_count2
# 27 no_count3
# 28 no_count4
# 29 no_count5
# 30 passenger_count0
# 31 passenger_count1
# 32 passenger_count2
# 33 passenger_count3
# 34 passenger_count4
# 35 passenger_count5
# 36 passenger_model0
# 37 passenger_model1
# 38 passenger_model2
# 39 passenger_model3
# 40 passenger_model4
# 41 passenger_model5
# 42 passenger_model_avg0
# 43 passenger_model_avg1
# 44 passenger_model_avg2
# 45 passenger_model_avg3
# 46 passenger_model_avg4
# 47 passenger_model_avg5
# 48 vehicle_model0
# 49 vehicle_model1
# 50 vehicle_model2
# 51 vehicle_model3
# 52 vehicle_model4
# 53 vehicle_model5
# 54 vehicle_model_avg0
# 55 vehicle_model_avg1
# 56 vehicle_model_avg2
# 57 vehicle_model_avg3
# 58 vehicle_model_avg4
# 59 vehicle_model_avg5
# 60 volume0
# 61 volume1
# 62 volume2
# 63 volume3
# 64 volume4
# 65 volume5
# 66 vehicle_all_model
# 67 cargo_all_model
# 68 passenger_all_model
# 69 no_all_count
# 70 cargo_all_count
# 71 passenger_all_count
# 72 volume_all
# 73 etc_all_count
# 74 vehicle_all_model_avg
# 75 cargo_all_model_avg
# 76 passenger_all_model_avg
# 77 hour
# 78 minute

# %%
volume_entry_train = pd.read_csv("volume_exit_train_1Soffset0.csv",index_col="Unnamed: 0")
for i in range(len(volume_entry_train.columns)):
    print str(i) + " " + volume_entry_train.columns[i]
# Out:
# 0 cargo_count0
# 1 cargo_count1
# 2 cargo_count2
# 3 cargo_count3
# 4 cargo_count4
# 5 cargo_count5
# 6 cargo_model0
# 7 cargo_model1
# 8 cargo_model2
# 9 cargo_model3
# 10 cargo_model4
# 11 cargo_model5
# 12 cargo_model_avg0
# 13 cargo_model_avg1
# 14 cargo_model_avg2
# 15 cargo_model_avg3
# 16 cargo_model_avg4
# 17 cargo_model_avg5
# 18 etc_count0
# 19 etc_count1
# 20 etc_count2
# 21 etc_count3
# 22 etc_count4
# 23 etc_count5
# 24 no_count0
# 25 no_count1
# 26 no_count2
# 27 no_count3
# 28 no_count4
# 29 no_count5
# 30 passenger_count0
# 31 passenger_count1
# 32 passenger_count2
# 33 passenger_count3
# 34 passenger_count4
# 35 passenger_count5
# 36 passenger_model0
# 37 passenger_model1
# 38 passenger_model2
# 39 passenger_model3
# 40 passenger_model4
# 41 passenger_model5
# 42 passenger_model_avg0
# 43 passenger_model_avg1
# 44 passenger_model_avg2
# 45 passenger_model_avg3
# 46 passenger_model_avg4
# 47 passenger_model_avg5
# 48 vehicle_model0
# 49 vehicle_model1
# 50 vehicle_model2
# 51 vehicle_model3
# 52 vehicle_model4
# 53 vehicle_model5
# 54 vehicle_model_avg0
# 55 vehicle_model_avg1
# 56 vehicle_model_avg2
# 57 vehicle_model_avg3
# 58 vehicle_model_avg4
# 59 vehicle_model_avg5
# 60 volume0
# 61 volume1
# 62 volume2
# 63 volume3
# 64 volume4
# 65 volume5
# 66 y
# 67 vehicle_all_model
# 68 cargo_all_model
# 69 passenger_all_model
# 70 no_all_count
# 71 cargo_all_count
# 72 passenger_all_count
# 73 volume_all
# 74 etc_all_count
# 75 vehicle_all_model_avg
# 76 cargo_all_model_avg
# 77 passenger_all_model_avg
# 78 hour
# 79 minute
