# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("test_offset0.csv", index_col="Unnamed: 0")
data.shape
# Out:
# (70, 135)

# %%
print data
# Out:
#                      cargo_all_count  cargo_all_model  cargo_all_model_avg  \
# 2016-09-19 00:00:00             12.0             49.0             4.083333
# 2016-09-19 02:00:00             24.0             78.0             3.250000
# 2016-09-19 04:00:00             17.0             46.0             2.705882
# 2016-09-19 06:00:00             13.0             30.0             2.307692
# 2016-09-19 08:00:00             27.0             58.0             2.148148
# 2016-09-19 10:00:00             23.0             52.0             2.260870
# 2016-09-19 12:00:00             28.0             62.0             2.214286
# 2016-09-19 14:00:00             28.0             61.0             2.178571
# 2016-09-19 16:00:00             17.0             37.0             2.176471
# 2016-09-19 18:00:00             12.0             28.0             2.333333
# 2016-09-19 20:00:00              9.0             18.0             2.000000
# ...

# %%
data.columns
# Out:
# Index([u'cargo_all_count', u'cargo_all_model', u'cargo_all_model_avg',
#        u'cargo_count0', u'cargo_count1', u'cargo_count2', u'cargo_count3',
#        u'cargo_count4', u'cargo_count5', u'cargo_model0',
#        ...
#        u'volume5', u'volume5_S2', u'volume5_S3', u'volume5_sqrt',
#        u'volume_all', u'volume_all_S2', u'volume_all_S3', u'volume_all_sqrt',
#        u'week', u'weekend'],
#       dtype='object', length=135)
