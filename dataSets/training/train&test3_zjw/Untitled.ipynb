# %%
import pandas as pd

# %%
data_df = pd.read_csv("test_offset0.csv", index_col="Unnamed: 0")
data_df.head()
# Out:
#                      day direction hour  is_eight  is_eighteen  is_nine  \
# 2016-10-18 06:00:00  18D     entry   9H       0.0          0.0      1.0
# 2016-10-18 15:00:00  18D     entry  18H       0.0          1.0      0.0
# 2016-10-19 06:00:00  19D     entry   9H       0.0          0.0      1.0
# 2016-10-19 15:00:00  19D     entry  18H       0.0          1.0      0.0
# 2016-10-20 06:00:00  20D     entry   9H       0.0          0.0      1.0
#
#                      is_seventeen minute tollgate_id  vehicle_model0   ...     \
# 2016-10-18 06:00:00           0.0    40M          1S            13.0   ...
# 2016-10-18 15:00:00           0.0    40M          1S            56.0   ...
# 2016-10-19 06:00:00           0.0    40M          1S            14.0   ...
# 2016-10-19 15:00:00           0.0    40M          1S            45.0   ...
# 2016-10-20 06:00:00           0.0    40M          1S             9.0   ...
#
#                      vehicle_model4  vehicle_model5  volume0  volume1  \
# ...

# %%
index_se = pd.Series(data_df.index + "-" + data_df["direction"] + "-0")

# %%
index_se
# Out:
# 0     2016-10-18 06:00:00-entry-0
# 1     2016-10-18 15:00:00-entry-0
# 2     2016-10-19 06:00:00-entry-0
# 3     2016-10-19 15:00:00-entry-0
# 4     2016-10-20 06:00:00-entry-0
# 5     2016-10-20 15:00:00-entry-0
# 6     2016-10-21 06:00:00-entry-0
# 7     2016-10-21 15:00:00-entry-0
# 8     2016-10-22 06:00:00-entry-0
# 9     2016-10-22 15:00:00-entry-0
# 10    2016-10-23 06:00:00-entry-0
# 11    2016-10-23 15:00:00-entry-0
# 12    2016-10-24 06:00:00-entry-0
# 13    2016-10-24 15:00:00-entry-0
# 14     2016-10-18 06:00:00-exit-0
# 15     2016-10-18 15:00:00-exit-0
# 16     2016-10-19 06:00:00-exit-0
# 17     2016-10-19 15:00:00-exit-0
# 18     2016-10-20 06:00:00-exit-0
# 19     2016-10-20 15:00:00-exit-0
# 20     2016-10-21 06:00:00-exit-0
# 21     2016-10-21 15:00:00-exit-0
# 22     2016-10-22 06:00:00-exit-0
# 23     2016-10-22 15:00:00-exit-0
# 24     2016-10-23 06:00:00-exit-0
# 25     2016-10-23 15:00:00-exit-0
# 26     2016-10-24 06:00:00-exit-0
# ...
