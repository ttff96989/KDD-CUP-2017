# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test_df = pd.read_csv("./testing_phase1/volume(table 6)_test2.csv")
test_df.head()
# Out:
#                   time  tollgate_id  direction  vehicle_model  has_etc  \
# 0  2016-10-25 06:02:43            3          0              1        0
# 1  2016-10-25 06:01:05            3          0              1        0
# 2  2016-10-25 06:01:15            2          0              1        1
# 3  2016-10-25 06:01:19            3          0              1        0
# 4  2016-10-25 06:02:57            3          0              1        0
#
#    vehicle_type
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# 不规则点包括：1端口0方向10月30日下午高、2端口0方向10月30日上午低；10月30日下午低；10月31日下午低、3端口0方向10月28日下午高；10月30日下午高
#               3端口1方向10月28日下午略高；10月30日下午高
test1 = test_df.copy()
tollgate_id = 3
direction = 0
test1["time"] = test1["time"].apply(pd.Timestamp)
test1.index = test1["time"]
test1["volume"] = 1
test1["day"] = test1["time"].apply(lambda x: x.day)
for offset in range(7):
    temp = test1[(test1["tollgate_id"] == tollgate_id) & 
                (test1["direction"] == direction) & 
                (test1["day"] == 25 + offset)][["volume"]].resample("20T").sum().dropna()
    temp.plot()

# %%
test1_df = pd.read_csv("./testing_phase1/volume(table 6)_test1.csv")
test1_df.head()
# Out:
#                   time  tollgate_id  direction  vehicle_model  has_etc  \
# 0  2016-10-18 07:59:04            2          0              1        1
# 1  2016-10-18 07:59:31            2          0              1        1
# 2  2016-10-18 07:59:50            2          0              1        1
# 3  2016-10-18 07:32:33            3          0              1        1
# 4  2016-10-18 07:32:46            3          0              1        1
#
#    vehicle_type
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
test1 = test1_df.copy()
tollgate_id = 3
direction = 0
test1["time"] = test1["time"].apply(pd.Timestamp)
test1.index = test1["time"]
test1["volume"] = 1
test1["day"] = test1["time"].apply(lambda x: x.day)
for offset in range(7):
    temp = test1[(test1["tollgate_id"] == tollgate_id) & 
                (test1["direction"] == direction) & 
                (test1["day"] == 18 + offset)][["volume"]].resample("20T").sum().dropna()
    temp.plot()
    plt.show()
